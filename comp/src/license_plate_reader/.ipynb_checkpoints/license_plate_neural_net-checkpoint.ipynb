# %%
import math
import numpy as np
import re

import tensorflow
import keras 
import jupyter
import cv2

from collections import Counter
from matplotlib import pyplot as plt
from PIL import Image, ImageFont

PIC_PATH = "/home/fizzer/enph353_git/beep-boop/comp/src/license_plate_reader/blurred_plates"
raw_labels = !ls {PIC_PATH}

files_set = [list(filter(None, re.split('\t|\s', raw_label))) for raw_label in raw_labels]
# print(files_set)

files = []
for file in files_set:
  files = files + file
print(files)

labels_split = [list(filter(None, re.split(r'[_,.]', file))) for file in files]

labels = []
for label in labels_split:
  labels.append(label[1])
print(labels)

# # Blurred plates
# PIC_PATH_BLUR = "drive/My\ Drive/Academics/UBC/2019-2020/ENPH353/comp/blurred_plates"
# raw_labels = !ls {PIC_PATH_BLUR}

# files_set_blurred = [list(filter(None, re.split('\t|\s', raw_label))) for raw_label in raw_labels]
# # print(files_set)

# files_blurred = []
# for file in files_set_blurred:
#   files_blurred = files_blurred + file
# print(files_blurred)

# labels_split_blurred = [list(filter(None, re.split(r'[_,.]', file))) for file in files_blurred]

# labels_blurred = []
# for label in labels_split_blurred:
#   labels_blurred.append(label[1])
# print(labels_blurred)

LOAD_PATH = "/home/fizzer/enph353_git/beep-boop/comp/src/license_plate_reader/blurred_plates"
# LOAD_PATH_BLURRED = "drive/My Drive/Academics/UBC/2019-2020/ENPH353/comp/blurred_plates"

imgset = np.array([np.array(Image.open(f'{LOAD_PATH}/{file}'))
                    for file in files[:]])

# imgset_blurred = np.array([np.array(Image.open(f'{LOAD_PATH_BLURRED}/{file}'))
#                     for file in files_blurred[:]])

print("Loaded {:} images from folder".format(imgset.shape[0]))
# print("Loaded {:} images from blurred folder".format(imgset_blurred.shape[0]))

# H_OFFSET = 14
# VT_LIM = 90
# VB_LIM = VT_LIM + 128

all_chars = []

# Initializations to get cuts
interval = 200
start = [50, 350]
l_cuts = np.linspace(start[0], start[0] + interval, num=3, dtype=int)
r_cuts = np.linspace(start[1], start[1] + interval, num=3, dtype=int)

def match_char(img, label, char_imgset):
  
  char_imgs = []
  char_imgs.append(img[30:268,l_cuts[0]:l_cuts[1]])
  char_imgs.append(img[30:268,l_cuts[1]:l_cuts[2]])
  char_imgs.append(img[30:268,r_cuts[0]:r_cuts[1]])
  char_imgs.append(img[30:268,r_cuts[1]:r_cuts[2]])
  # char_imgs.append(img[VT_LIM:VB_LIM,l_cuts[0]-H_OFFSET:l_cuts[1]+H_OFFSET])
  # char_imgs.append(img[VT_LIM:VB_LIM,l_cuts[1]-H_OFFSET:l_cuts[2]+H_OFFSET])
  # char_imgs.append(img[VT_LIM:VB_LIM,r_cuts[0]-H_OFFSET:r_cuts[1]+H_OFFSET])
  # char_imgs.append(img[VT_LIM:VB_LIM,r_cuts[1]-H_OFFSET:r_cuts[2]+H_OFFSET])

  char_labels = []
  for letter in label:
    alpha_num = ord(letter)
    if alpha_num <= 57:
      char_labels.append(alpha_num - 48)
    else:
      char_labels.append(alpha_num - 55)

  ######## Useful print outputs #########

  # print(label)
  # print(char_labels)
  # [print(chr(letter)) for letter in char_labels]

  # cv2_imshow(char_imgs[0])
  # cv2_imshow(char_imgs[1])
  # cv2_imshow(char_imgs[2])
  # cv2_imshow(char_imgs[3])

  [char_imgset.append(np.array([img, label]))
                    for img, label in zip(char_imgs, char_labels)]

char_imgset = []

for img, label in zip(imgset, labels):
  match_char(img, label, char_imgset)

# Shuffle the dataset
np.random.shuffle(char_imgset)

# Generate X and Y datasets
X_dataset_orig = np.array([data[0] for data in char_imgset])
Y_dataset_orig = np.array([[data[1]] for data in char_imgset]).T

NUMBER_OF_LABELS = 36
CONFIDENCE_THRESHOLD = 0.01

def convert_to_one_hot(Y, C):
    Y = np.eye(C)[Y.reshape(-1)].T
    return Y
  
# Normalize X (images) dataset
X_dataset = X_dataset_orig/255.

# Convert Y dataset to one-hot encoding
Y_dataset = convert_to_one_hot(Y_dataset_orig, NUMBER_OF_LABELS).T

VALIDATION_SPLIT = 0.2

print("Total examples: {:d}\nTraining examples: {:d}\nTest examples: {:d}".
      format(X_dataset.shape[0],
             math.ceil(X_dataset.shape[0] * (1-VALIDATION_SPLIT)),
             math.floor(X_dataset.shape[0] * VALIDATION_SPLIT)))
print("X shape: " + str(X_dataset.shape))
print("Y shape: " + str(Y_dataset.shape))

from ipywidgets import interact
import ipywidgets as ipywidgets

# Display images in the training data set. 
def displayImage(index):
  plt.imshow(X_dataset[index])
  caption = ("y = " + str(Y_dataset[index]))#str(np.squeeze(Y_dataset_orig[:, index])))
  plt.text(0.5, 0.5, caption, 
           color='orange', fontsize = 20,
           horizontalalignment='left', verticalalignment='top')

# interact(displayImage, 
#         index=ipywidgets.IntSlider(min=0, max=X_dataset_orig.shape[0],
#                                    step=1, value=10))
displayImage(1)
# Out:
# ['plate_AA28.png', 'plate_AA76.png', 'plate_AB89.png', 'plate_AC71.png', 'plate_AD16.png', 'plate_AD91.png', 'plate_AE80.png', 'plate_AJ25.png', 'plate_AJ76.png', 'plate_AJ85.png', 'plate_AQ30.png', 'plate_AQ71.png', 'plate_AR85.png', 'plate_AS38.png', 'plate_AV96.png', 'plate_AW49.png', 'plate_AX61.png', 'plate_AY11.png', 'plate_BA69.png', 'plate_BG21.png', 'plate_BG98.png', 'plate_BJ06.png', 'plate_BM00.png', 'plate_BN05.png', 'plate_BR59.png', 'plate_BS78.png', 'plate_BV35.png', 'plate_BX53.png', 'plate_BY73.png', 'plate_BZ37.png', 'plate_CC56.png', 'plate_CD68.png', 'plate_CI14.png', 'plate_CI65.png', 'plate_CI95.png', 'plate_CJ12.png', 'plate_CJ42.png', 'plate_CK58.png', 'plate_CM21.png', 'plate_CN27.png', 'plate_CP78.png', 'plate_CQ09.png', 'plate_CX77.png', 'plate_CX80.png', 'plate_DB15.png', 'plate_DC23.png', 'plate_DE65.png', 'plate_DG58.png', 'plate_DI38.png', 'plate_DI96.png', 'plate_DO88.png', 'plate_DP65.png', 'plate_DS09.png', 'plate_DS35.png', 'plate_DX04.png', 'plate_DY18.png', 'plate_DY86.png', 'plate_DZ77.png', 'plate_EC96.png', 'plate_EJ31.png', 'plate_EN22.png', 'plate_EQ61.png', 'plate_EU11.png', 'plate_EU33.png', 'plate_EW09.png', 'plate_EW70.png', 'plate_EZ81.png', 'plate_FB38.png', 'plate_FB89.png', 'plate_FC36.png', 'plate_FC80.png', 'plate_FI12.png', 'plate_FJ17.png', 'plate_FK95.png', 'plate_FL02.png', 'plate_FR43.png', 'plate_FY11.png', 'plate_GB73.png', 'plate_GD40.png', 'plate_GD51.png', 'plate_GF59.png', 'plate_GJ04.png', 'plate_GJ12.png', 'plate_GO80.png', 'plate_GP01.png', 'plate_GP30.png', 'plate_GR67.png', 'plate_GS05.png', 'plate_GW36.png', 'plate_GX07.png', 'plate_GX99.png', 'plate_GZ04.png', 'plate_HA17.png', 'plate_HB36.png', 'plate_HE69.png', 'plate_HE70.png', 'plate_HH79.png', 'plate_HK70.png', 'plate_HO13.png', 'plate_HP17.png', 'plate_HQ62.png', 'plate_HU25.png', 'plate_HV51.png', 'plate_HV76.png', 'plate_HW56.png', 'plate_HW90.png', 'plate_HX30.png', 'plate_IA14.png', 'plate_IA67.png', 'plate_IC64.png', 'plate_IC77.png', 'plate_IC83.png', 'plate_IF10.png', 'plate_II13.png', 'plate_IK50.png', 'plate_IO06.png', 'plate_IO83.png', 'plate_IQ66.png', 'plate_IT13.png', 'plate_IT96.png', 'plate_IV52.png', 'plate_IV61.png', 'plate_IY26.png', 'plate_JA23.png', 'plate_JA24.png', 'plate_JA93.png', 'plate_JB15.png', 'plate_JF88.png', 'plate_JR42.png', 'plate_JV60.png', 'plate_JV90.png', 'plate_JY02.png', 'plate_JY09.png', 'plate_KA27.png', 'plate_KB07.png', 'plate_KE16.png', 'plate_KF01.png', 'plate_KF70.png', 'plate_KI67.png', 'plate_KI92.png', 'plate_KN74.png', 'plate_KN96.png', 'plate_KP17.png', 'plate_KS24.png', 'plate_KT28.png', 'plate_KV61.png', 'plate_KV98.png', 'plate_KX35.png', 'plate_LB15.png', 'plate_LB88.png', 'plate_LE32.png', 'plate_LI17.png', 'plate_LI55.png', 'plate_LJ74.png', 'plate_LO21.png', 'plate_LO70.png', 'plate_LQ62.png', 'plate_LR81.png', 'plate_LS58.png', 'plate_LU91.png', 'plate_LU98.png', 'plate_MC71.png', 'plate_MD56.png', 'plate_MD93.png', 'plate_MF71.png', 'plate_MI96.png', 'plate_MT85.png', 'plate_MV61.png', 'plate_MW83.png', 'plate_NC48.png', 'plate_ND99.png', 'plate_NF41.png', 'plate_NH35.png', 'plate_NH37.png', 'plate_NJ43.png', 'plate_NL60.png', 'plate_NM25.png', 'plate_NN17.png', 'plate_NO23.png', 'plate_NP71.png', 'plate_NP72.png', 'plate_NQ69.png', 'plate_NR09.png', 'plate_NR20.png', 'plate_NR85.png', 'plate_NT08.png', 'plate_NZ43.png', 'plate_NZ69.png', 'plate_OB13.png', 'plate_OD34.png', 'plate_OH27.png', 'plate_OI36.png', 'plate_OK03.png', 'plate_OP55.png', 'plate_OQ26.png', 'plate_OS10.png', 'plate_OS24.png', 'plate_OW28.png', 'plate_OW53.png', 'plate_OW92.png', 'plate_OX94.png', 'plate_PB05.png', 'plate_PB30.png', 'plate_PC16.png', 'plate_PD11.png', 'plate_PE12.png', 'plate_PE71.png', 'plate_PF86.png', 'plate_PG37.png', 'plate_PI46.png', 'plate_PJ90.png', 'plate_PL33.png', 'plate_PN08.png', 'plate_PN14.png', 'plate_PO44.png', 'plate_PR01.png', 'plate_PR33.png', 'plate_PU75.png', 'plate_QA32.png', 'plate_QB99.png', 'plate_QC18.png', 'plate_QD68.png', 'pl ...
# ['AA28', 'AA76', 'AB89', 'AC71', 'AD16', 'AD91', 'AE80', 'AJ25', 'AJ76', 'AJ85', 'AQ30', 'AQ71', 'AR85', 'AS38', 'AV96', 'AW49', 'AX61', 'AY11', 'BA69', 'BG21', 'BG98', 'BJ06', 'BM00', 'BN05', 'BR59', 'BS78', 'BV35', 'BX53', 'BY73', 'BZ37', 'CC56', 'CD68', 'CI14', 'CI65', 'CI95', 'CJ12', 'CJ42', 'CK58', 'CM21', 'CN27', 'CP78', 'CQ09', 'CX77', 'CX80', 'DB15', 'DC23', 'DE65', 'DG58', 'DI38', 'DI96', 'DO88', 'DP65', 'DS09', 'DS35', 'DX04', 'DY18', 'DY86', 'DZ77', 'EC96', 'EJ31', 'EN22', 'EQ61', 'EU11', 'EU33', 'EW09', 'EW70', 'EZ81', 'FB38', 'FB89', 'FC36', 'FC80', 'FI12', 'FJ17', 'FK95', 'FL02', 'FR43', 'FY11', 'GB73', 'GD40', 'GD51', 'GF59', 'GJ04', 'GJ12', 'GO80', 'GP01', 'GP30', 'GR67', 'GS05', 'GW36', 'GX07', 'GX99', 'GZ04', 'HA17', 'HB36', 'HE69', 'HE70', 'HH79', 'HK70', 'HO13', 'HP17', 'HQ62', 'HU25', 'HV51', 'HV76', 'HW56', 'HW90', 'HX30', 'IA14', 'IA67', 'IC64', 'IC77', 'IC83', 'IF10', 'II13', 'IK50', 'IO06', 'IO83', 'IQ66', 'IT13', 'IT96', 'IV52', 'IV61', 'IY26', 'JA23', 'JA24', 'JA93', 'JB15', 'JF88', 'JR42', 'JV60', 'JV90', 'JY02', 'JY09', 'KA27', 'KB07', 'KE16', 'KF01', 'KF70', 'KI67', 'KI92', 'KN74', 'KN96', 'KP17', 'KS24', 'KT28', 'KV61', 'KV98', 'KX35', 'LB15', 'LB88', 'LE32', 'LI17', 'LI55', 'LJ74', 'LO21', 'LO70', 'LQ62', 'LR81', 'LS58', 'LU91', 'LU98', 'MC71', 'MD56', 'MD93', 'MF71', 'MI96', 'MT85', 'MV61', 'MW83', 'NC48', 'ND99', 'NF41', 'NH35', 'NH37', 'NJ43', 'NL60', 'NM25', 'NN17', 'NO23', 'NP71', 'NP72', 'NQ69', 'NR09', 'NR20', 'NR85', 'NT08', 'NZ43', 'NZ69', 'OB13', 'OD34', 'OH27', 'OI36', 'OK03', 'OP55', 'OQ26', 'OS10', 'OS24', 'OW28', 'OW53', 'OW92', 'OX94', 'PB05', 'PB30', 'PC16', 'PD11', 'PE12', 'PE71', 'PF86', 'PG37', 'PI46', 'PJ90', 'PL33', 'PN08', 'PN14', 'PO44', 'PR01', 'PR33', 'PU75', 'QA32', 'QB99', 'QC18', 'QD68', 'QE04', 'QE84', 'QH37', 'QL88', 'QO12', 'QO88', 'QP61', 'QQ86', 'QR17', 'QS26', 'QT55', 'RA36', 'RB14', 'RD10', 'RI33', 'RJ41', 'RJ71', 'RN68', 'RS13', 'RS21', 'RT91', 'RU05', 'RW30', 'RW93', 'RY94', 'SD50', 'SD52', 'SG04', 'SI45', 'SI82', 'SO45', 'SP62', 'SQ39', 'SR32', 'SS00', 'SS62', 'ST21', 'SY14', 'SY93', 'TA01', 'TA25', 'TF08', 'TF42', 'TH88', 'TL49', 'TM72', 'TP46', 'TS41', 'TS85', 'TX34', 'TX98', 'UC30', 'UC46', 'UF81', 'UG80', 'UG99', 'UH48', 'UM99', 'UN06', 'UR41', 'US17', 'US42', 'UU52', 'UV22', 'UW90', 'UY70', 'UZ85', 'VA10', 'VA50', 'VF06', 'VI41', 'VJ44', 'VK75', 'VL82', 'VN83', 'VT89', 'VW55', 'VY25', 'WE85', 'WF32', 'WF67', 'WG99', 'WJ02', 'WJ97', 'WN70', 'WN94', 'WO31', 'WO67', 'WS03', 'WS87', 'WS91', 'WS99', 'WT35', 'XD85', 'XE41', 'XG55', 'XH17', 'XH87', 'XI63', 'XJ77', 'XM05', 'XO49', 'XP83', 'XU49', 'XU63', 'XV02', 'XZ23', 'YA53', 'YB76', 'YC48', 'YC63', 'YE56', 'YL66', 'YM84', 'YP31', 'YS89', 'YY92', 'YZ06', 'ZA14', 'ZA48', 'ZH01', 'ZI02', 'ZI86', 'ZJ55', 'ZM22', 'ZO23', 'ZQ41', 'ZR42', 'ZS67', 'ZT06', 'ZT13', 'ZT65', 'ZT79', 'ZV35', 'ZW12', 'ZW19', 'ZW74', 'ZX99']
# Loaded 360 images from folder
# Total examples: 1440
# Training examples: 1152
# Test examples: 288
# X shape: (1440, 238, 100, 3)
# Y shape: (1440, 36)

# %%
# train model 
from keras import layers
from keras import models
from keras import optimizers

from keras.utils import plot_model
from keras import backend

def reset_weights(model):
    session = backend.get_session()
    for layer in model.layers: 
        if hasattr(layer, 'kernel_initializer'):
            layer.kernel.initializer.run(session=session)
            
conv_model = models.Sequential()
conv_model.add(layers.Conv2D(32, (3, 3), activation='relu',
                             input_shape=(238, 100, 3)))
conv_model.add(layers.MaxPooling2D((2, 2)))
conv_model.add(layers.Conv2D(64, (3, 3), activation='relu'))
conv_model.add(layers.MaxPooling2D((2, 2)))
conv_model.add(layers.Conv2D(128, (3, 3), activation='relu'))
conv_model.add(layers.MaxPooling2D((2, 2)))
conv_model.add(layers.Conv2D(128, (3, 3), activation='relu'))
conv_model.add(layers.MaxPooling2D((2, 2)))
conv_model.add(layers.Flatten())
conv_model.add(layers.Dropout(0.5))
conv_model.add(layers.Dense(512, activation='relu'))
conv_model.add(layers.Dense(36, activation='softmax'))

conv_model.summary()

LEARNING_RATE = 1e-4
conv_model.compile(loss='categorical_crossentropy',
                   optimizer=optimizers.RMSprop(lr=LEARNING_RATE),
                   metrics=['acc'])

history_conv = conv_model.fit(X_dataset, Y_dataset, 
                              validation_split=VALIDATION_SPLIT, 
                              epochs=20, 
                              batch_size=16)

plt.plot(history_conv.history['loss'])
plt.plot(history_conv.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'val loss'], loc='upper left')
plt.show()

plt.plot(history_conv.history['acc'])
plt.plot(history_conv.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy (%)')
plt.xlabel('epoch')
plt.legend(['train accuracy', 'val accuracy'], loc='upper left')
plt.show()

# test model
def decode_val(index):
  if(index < 10):
    index += 48
  else:
    index += 55
  
  return chr(index)

# Display images in the training data set. 
def displayImage(index):
  img = X_dataset[index]
  
  img_aug = np.expand_dims(img, axis=0)
  y_predict = conv_model.predict(img_aug)[0]

  actual_index = np.argmax(Y_dataset[index])
  pred_index = np.argmax(y_predict)
  
  plt.imshow(img)  
  caption = ("Actual value: {}\nPredicted value: {}".
             format(decode_val(actual_index), decode_val(pred_index)))
  plt.text(0.5, 0.5, caption, 
           color='orange', fontsize = 16,
           horizontalalignment='left', verticalalignment='bottom')


# interact(displayImage, 
#         index=ipywidgets.IntSlider(min=0, max=X_dataset_orig.shape[0],
#                                    step=1, value=10))
displayImage(355)

# plot confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

y_true = []
y_pred_dataset= []
y_pred = []
CM_labels = []

# Get all predicted values, then perform alphanumeric conversion for predicted value indices
[y_pred_dataset.append(conv_model.predict(np.expand_dims(X_data, axis=0))[0]) for X_data in X_dataset]
[y_pred.append(decode_val(np.argmax(index))) for index in y_pred_dataset]

# Alphanumeric conversion for true value indices
[y_true.append(decode_val(np.argmax(index))) for index in Y_dataset]

# Generate labels for confusion matrix
[CM_labels.append(decode_val(i)) for i in range(0, 36)]

np.set_printoptions(threshold=np.inf)
cm = confusion_matrix(y_true, y_pred, CM_labels)

df_cm = pd.DataFrame(cm, index = [i for i in CM_labels],
                  columns = [i for i in CM_labels])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True)

error_count = 0

print("TOP LOSSES:")

for a in range(0, 36):
  for b in range(0, 36):
    if cm[a][b] != 0 and a != b:
      error_count += 1
      print("Number of occurrences: {}". format(cm[a][b]))
      print("Actual value: {}". format(decode_val(a)))
      print("Predicted value: {}\n". format(decode_val(b)))

if error_count == 0:
  print("No errors in predictions!")

# save model
SAVE_PATH = "/home/fizzer/enph353_git/beep-boop/comp/src/license_plate_reader" 
model_json = conv_model.to_json()

# Save model to JSON
with open("blur_license_plate_model.json", "w") as json_file:
    json_file.write(model_json)
# Serialize weights to HDF5
conv_model.save_weights("blur_license_plate_model.h5")

# !cp -r blur_license_plate_model.json {SAVE_PATH}
# !cp -r blur_license_plate_model.h5 {SAVE_PATH}

print("Saved blur_license_plate_model.json and blur_license_plate_model.h5 to comp folder")
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 236, 98, 32)       896
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 118, 49, 32)       0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 116, 47, 64)       18496
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 58, 23, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 56, 21, 128)       73856
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 28, 10, 128)       0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 26, 8, 128)        147584
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 13, 4, 128)        0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 6656)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 6656)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 512)               3408384
# _________________________________________________________________
# dense_12 (Dense)             (None, 36)                18468
# =================================================================
# Total params: 3,667,684
# Trainable params: 3,667,684
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1152 samples, validate on 288 samples
# Epoch 1/20
# 1152/1152 [==============================] - 42s 37ms/step - loss: 3.4514 - acc: 0.0920 - val_loss: 3.4023 - val_acc: 0.0972
# Epoch 2/20
# 1152/1152 [==============================] - 44s 38ms/step - loss: 2.9039 - acc: 0.3203 - val_loss: 1.9575 - val_acc: 0.5486
# Epoch 3/20
# 1152/1152 [==============================] - 46s 40ms/step - loss: 0.9228 - acc: 0.7969 - val_loss: 0.2151 - val_acc: 0.9549
# Epoch 4/20
# 1152/1152 [==============================] - 43s 37ms/step - loss: 0.1389 - acc: 0.9670 - val_loss: 0.0473 - val_acc: 0.9826
# Epoch 5/20
# 1152/1152 [==============================] - 42s 36ms/step - loss: 0.0404 - acc: 0.9896 - val_loss: 0.0074 - val_acc: 1.0000
# Epoch 6/20
# 1152/1152 [==============================] - 42s 36ms/step - loss: 0.0162 - acc: 0.9957 - val_loss: 0.0278 - val_acc: 0.9792
# Epoch 7/20
# 1152/1152 [==============================] - 42s 36ms/step - loss: 0.0076 - acc: 0.9974 - val_loss: 3.4510e-04 - val_acc: 1.0000
# Epoch 8/20
# 1152/1152 [==============================] - 42s 36ms/step - loss: 0.0041 - acc: 0.9991 - val_loss: 4.8315e-05 - val_acc: 1.0000
# Epoch 9/20
# 1152/1152 [==============================] - 42s 37ms/step - loss: 0.0065 - acc: 0.9983 - val_loss: 0.0018 - val_acc: 1.0000
# Epoch 10/20
# 1152/1152 [==============================] - 42s 36ms/step - loss: 9.0951e-04 - acc: 1.0000 - val_loss: 6.0763e-05 - val_acc: 1.0000
# Epoch 11/20
# 1152/1152 [==============================] - 42s 36ms/step - loss: 0.0044 - acc: 0.9991 - val_loss: 3.2434e-06 - val_acc: 1.0000
# Epoch 12/20
# 1152/1152 [==============================] - 42s 36ms/step - loss: 0.0031 - acc: 0.9991 - val_loss: 1.5460e-06 - val_acc: 1.0000
# Epoch 13/20
# 1152/1152 [==============================] - 42s 37ms/step - loss: 6.1407e-05 - acc: 1.0000 - val_loss: 3.1168e-07 - val_acc: 1.0000
# Epoch 14/20
# 1152/1152 [==============================] - 42s 36ms/step - loss: 0.0012 - acc: 0.9991 - val_loss: 2.3097e-07 - val_acc: 1.0000
# Epoch 15/20
# 1152/1152 [==============================] - 42s 36ms/step - loss: 1.9749e-05 - acc: 1.0000 - val_loss: 4.2545e-06 - val_acc: 1.0000
# Epoch 16/20
# 1152/1152 [==============================] - 44s 38ms/step - loss: 3.2139e-04 - acc: 1.0000 - val_loss: 5.9687e-07 - val_acc: 1.0000
# Epoch 17/20
# 1152/1152 [==============================] - 42s 37ms/step - loss: 0.0111 - acc: 0.9991 - val_loss: 1.9661e-07 - val_acc: 1.0000
# Epoch 18/20
# 1152/1152 [==============================] - 42s 37ms/step - loss: 1.1916e-06 - acc: 1.0000 - val_loss: 9.5202e-09 - val_acc: 1.0000
# Epoch 19/20
# 1152/1152 [==============================] - 42s 37ms/step - loss: 6.9843e-04 - acc: 0.9991 - val_loss: 3.2286e-07 - val_acc: 1.0000
# Epoch 20/20
# 1152/1152 [==============================] - 43s 37ms/step - loss: 5.5355e-06 - acc: 1.0000 - val_loss: 0.0000e+00 - val_acc: 1.0000
# TOP LOSSES:
# No errors in predictions!
# cp: 'blur_license_plate_model.json' and '/home/fizzer/enph353_git/beep-boop/comp/src/license_plate_reader/blur_license_plate_model.json' are the same file
# cp: 'blur_license_plate_model.h5' and '/home/fizzer/enph353_git/beep-boop/comp/src/license_plate_reader/blur_license_plate_model.h5' are the same file
# Saved blur_license_plate_model.json and blur_license_plate_model.h5 to comp folder
